# %%
import pandas as pd
import numpy as np
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
from yellowbrick.cluster import KElbowVisualizer
import random

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
link = 'hhttps://docs.google.com/spreadsheets/d/1baKBXDs_PiIIYyUFmq0UOCBcMwq6DWji/edit?usp=sharing&ouid=100934670427194582945&rtpof=true&sd=true'
id = '1baKBXDs_PiIIYyUFmq0UOCBcMwq6DWji'
print (id)
# Out:
# 1baKBXDs_PiIIYyUFmq0UOCBcMwq6DWji

# %%
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('sales_df_completed_uc.xlsx')
st_df1 = pd.read_excel('sales_df_completed_uc.xlsx')

# %%
st_df1.groupby('respond_to_discount').size()
# Out:
# respond_to_discount
# 0    21035
# 1     9521
# dtype: int64

# %%
st_df2= st_df1[st_df1['respond_to_discount'] == 1]
st_df2
# Out:
#        cust_id    status           category   payment_method  \
# 0            4  complete  Mobiles & Tablets  easypay_voucher
# 4           28  complete            Soghaat              cod
# 8           44  complete  Mobiles & Tablets          Payaxis
# 9           47  complete      Entertainment       Easypay_MA
# 14          71  complete         Appliances          Easypay
# ...        ...       ...                ...              ...
# 30489   106961  complete  Mobiles & Tablets      jazzvoucher
# 30491   106964  complete  Mobiles & Tablets      jazzvoucher
# 30497   106992  complete         Superstore      jazzvoucher
# 30509   107423  complete      Men's Fashion   customercredit
# 30538   111017  complete      Men's Fashion              cod
#
#                             E Mail  respond_to_discount  total_spent  \
# 0         reggie.doughty@gmail.com                    1  27394.19000
# 4         reinaldo.drain@yahoo.com                    1   3971.30000
# 8             kendall.ro@gmail.com                    1  10711.07900
# 9             jessie.schock@bp.com                    1  18548.33000
# 14     deetta.tucci@exxonmobil.com                    1  10151.17601
# ...                            ...                  ...          ...
# 30489       lakita.motes@gmail.com                    1   5852.39200
# 30491    samira.lanphear@yahoo.com                    1   4389.29400
# 30497  joe.guillemette@hotmail.com                    1    746.41400
# 30509       karole.goo@hotmail.com                    1   9627.53500
# 30538   britteny.mcvay@walmart.com                    1    147.50000
#
#        total_discount_received  no_of_transactions  \
# 0                   3406.01000                  41
# 4                    500.00000                  11
# 8                   1548.42100                   9
# 9                   4956.97000                  32
# 14                  1880.82399                  56
# ...                        ...                 ...
# 30489                678.80800                   4
# 30491                509.10600                   3
# 30497                126.58600                   4
# 30509                 90.99000                  10
# 30538                100.00000                   2
#
#        days_till_last_interaction  ...  age_binned_Middle_Age  \
# 0                              93  ...                      1
# 4                             224  ...                      0
# 8                             176  ...                      1
# 9                             158  ...                      1
# 14                            106  ...                      0
# ...                           ...  ...                    ...
# 30489                         206  ...                      1
# 30491                         206  ...                      0
# 30497                         206  ...                      0
# 30509                         136  ...                      0
# 30538                         154  ...                      1
#
#        age_binned_Old_age  Gender_F  Gender_M  Region_Midwest  \
# 0                       0         0         1               1
# 4                       1         0         1               0
# 8                       0         1         0               0
# 9                       0         0         1               0
# 14                      1         1         0               1
# ...                   ...       ...       ...             ...
# 30489                   0         1         0               0
# 30491                   0         1         0               1
# 30497                   0         0         1               0
# 30509                   0         1         0               0
# 30538                   0         1         0               0
#
#        Region_Northeast  Region_South  Region_West  cluster  cluster_Cat
# 0                     0             0            0        3            2
# 4                     0             0            1        0            5
# 8                     0             1            0        3            5
# 9                     1             0            0        3            0
# 14                    0             0            0        3            0
# ...                 ...           ...          ...      ...          ...
# 30489                 1             0            0        0            5
# 30491                 0             0            0        0            5
# 30497                 0             0            1        0            5
# 30509                 0             0            1        3            0
# 30538                 0             0            1        0            0
#
# [9521 rows x 23 columns]

# %%
len(st_df2)
# Out:
# 9521

# %% [markdown]
# **Simple Random Sampling**

# %% [markdown]
# Using https://www.calculator.net/sample-size-calculator.html?type=1&cl=95&ci=5&pp=50&ps=30556&x=67&y=14

# %%
population_total_discount_received_mean = round(st_df2['total_discount_received'].mean(),3)
population_total_discount_received_mean
# Out:
# 1459.16

# %% [markdown]
# **For 90% C.I : Sample size : 264**

# %%
# Define sample size
sample_size_ci90 = 264

# %%
# Set random seed
random.seed(42)

indices_ci90 = random.sample(range(len(st_df2)), sample_size_ci90)

# %%
random.seed(42)
sample1 = st_df2.iloc[indices_ci90]

# %%
sample1
# Out:
#        cust_id    status           category   payment_method  \
# 5280     58412  complete          Computing          Payaxis
# 1157     11521  complete  Mobiles & Tablets          Payaxis
# 13057    72572  complete  Mobiles & Tablets          Easypay
# 11833    70786  complete      Men's Fashion       Easypay_MA
# 11099    69712  complete         Appliances          Easypay
# ...        ...       ...                ...              ...
# 27402    94664  complete  Mobiles & Tablets  easypay_voucher
# 2830     31779  complete  Beauty & Grooming              cod
# 14290    74359  complete      Entertainment  easypay_voucher
# 2547     27761  complete      Men's Fashion          Easypay
# 2269     24073  complete      Men's Fashion          Easypay
#
#                                   E Mail  respond_to_discount  total_spent  \
# 5280          tomas.joslin@earthlink.net                    1     2738.620
# 1157   demetrius.matamoros@microsoft.com                    1     3224.406
# 13057          larhonda.stacks@gmail.com                    1     9821.525
# 11833              cinda.yeary@gmail.com                    1      306.900
# 11099           abbie.hartness@gmail.com                    1      444.905
# ...                                  ...                  ...          ...
# 27402       avril.wendling@earthlink.net                    1     9856.080
# 2830            clair.barnette@gmail.com                    1      874.800
# 14290               kit.doster@gmail.com                    1     7051.680
# 2547                reed.caverly@ibm.com                    1     7073.075
# 2269          cleo.butner@rediffmail.com                    1     2457.752
#
#        total_discount_received  no_of_transactions  \
# 5280                   578.680                   9
# 1157                   991.994                  27
# 13057                 1444.975                  11
# 11833                   34.100                  10
# 11099                   54.995                   1
# ...                        ...                 ...
# 27402                 1095.120                   4
# 2830                    20.000                  10
# 14290                  783.520                   4
# 2547                  1064.125                  30
# 2269                   476.138                   7
#
#        days_till_last_interaction  ...  age_binned_Middle_Age  \
# 5280                          106  ...                      1
# 1157                          197  ...                      0
# 13057                         229  ...                      1
# 11833                         375  ...                      1
# 11099                         376  ...                      1
# ...                           ...  ...                    ...
# 27402                         259  ...                      1
# 2830                          333  ...                      0
# 14290                         372  ...                      1
# 2547                          103  ...                      1
# 2269                          240  ...                      1
#
#        age_binned_Old_age  Gender_F  Gender_M  Region_Midwest  \
# 5280                    0         0         1               1
# 1157                    1         0         1               0
# 13057                   0         1         0               0
# 11833                   0         1         0               0
# 11099                   0         1         0               0
# ...                   ...       ...       ...             ...
# 27402                   0         1         0               0
# 2830                    1         0         1               1
# 14290                   0         1         0               1
# 2547                    0         0         1               0
# 2269                    0         0         1               0
#
#        Region_Northeast  Region_South  Region_West  cluster  cluster_Cat
# 5280                  0             0            0        0            5
# 1157                  1             0            0        0            5
# 13057                 1             0            0        3            5
# 11833                 0             1            0        0            0
# 11099                 1             0            0        0            5
# ...                 ...           ...          ...      ...          ...
# 27402                 0             1            0        3            2
# 2830                  0             0            0        0            5
# 14290                 0             0            0        0            5
# 2547                  0             1            0        0            0
# 2269                  1             0            0        0            0
#
# [264 rows x 23 columns]

# %% [markdown]
# **For 95% C.I : Sample size : 370**

# %%
# Define sample size
sample_size_ci95 = 370

# %%
random.seed(42)
indices_ci95 = random.sample(range(len(st_df2)), sample_size_ci95)

# %%
random.seed(42)
sample2 = st_df2.iloc[indices_ci95]

# %%
sample2
# Out:
#        cust_id    status           category   payment_method  \
# 5280     58412  complete          Computing          Payaxis
# 1157     11521  complete  Mobiles & Tablets          Payaxis
# 13057    72572  complete  Mobiles & Tablets          Easypay
# 11833    70786  complete      Men's Fashion       Easypay_MA
# 11099    69712  complete         Appliances          Easypay
# ...        ...       ...                ...              ...
# 27783    96483  complete         Appliances          Payaxis
# 7804     64621  complete      Men's Fashion              cod
# 11565    70396  complete      Entertainment  easypay_voucher
# 8671     66070  complete      Men's Fashion  easypay_voucher
# 9547     67411  complete      Entertainment          Easypay
#
#                                   E Mail  respond_to_discount  total_spent  \
# 5280          tomas.joslin@earthlink.net                    1     2738.620
# 1157   demetrius.matamoros@microsoft.com                    1     3224.406
# 13057          larhonda.stacks@gmail.com                    1     9821.525
# 11833              cinda.yeary@gmail.com                    1      306.900
# 11099           abbie.hartness@gmail.com                    1      444.905
# ...                                  ...                  ...          ...
# 27783           angel.maitland@gmail.com                    1    14378.504
# 7804           joe.fosdick@microsoft.com                    1      376.348
# 11565            wally.tiffany@gmail.com                    1     6516.000
# 8671           joellen.olmsted@gmail.com                    1    14962.160
# 9547             mui.junkins@verizon.net                    1     7022.285
#
#        total_discount_received  no_of_transactions  \
# 5280                   578.680                   9
# 1157                   991.994                  27
# 13057                 1444.975                  11
# 11833                   34.100                  10
# 11099                   54.995                   1
# ...                        ...                 ...
# 27783                 4568.296                   2
# 7804                    60.002                   8
# 11565                 1004.000                   4
# 8671                   556.040                  54
# 9547                  1948.815                   9
#
#        days_till_last_interaction  ...  age_binned_Middle_Age  \
# 5280                          106  ...                      1
# 1157                          197  ...                      0
# 13057                         229  ...                      1
# 11833                         375  ...                      1
# 11099                         376  ...                      1
# ...                           ...  ...                    ...
# 27783                         258  ...                      1
# 7804                          399  ...                      1
# 11565                         375  ...                      1
# 8671                          122  ...                      1
# 9547                          370  ...                      0
#
#        age_binned_Old_age  Gender_F  Gender_M  Region_Midwest  \
# 5280                    0         0         1               1
# 1157                    1         0         1               0
# 13057                   0         1         0               0
# 11833                   0         1         0               0
# 11099                   0         1         0               0
# ...                   ...       ...       ...             ...
# 27783                   0         0         1               1
# 7804                    0         0         1               0
# 11565                   0         0         1               0
# 8671                    0         1         0               1
# 9547                    1         1         0               0
#
#        Region_Northeast  Region_South  Region_West  cluster  cluster_Cat
# 5280                  0             0            0        0            5
# 1157                  1             0            0        0            5
# 13057                 1             0            0        3            5
# 11833                 0             1            0        0            0
# 11099                 1             0            0        0            5
# ...                 ...           ...          ...      ...          ...
# 27783                 0             0            0        3            5
# 7804                  0             1            0        0            0
# 11565                 0             0            1        0            5
# 8671                  0             0            0        3            2
# 9547                  0             0            1        0            5
#
# [370 rows x 23 columns]

# %% [markdown]
# **For 99% C.I : Sample size : 623**

# %%
# Define sample size
sample_size_ci99 = 621

# %%
random.seed(42)
indices_ci99 = random.sample(range(len(st_df2)), sample_size_ci99)

# %%
random.seed(42)
sample3 = st_df2.iloc[indices_ci99]

# %%
sample3
# Out:
#        cust_id    status           category   payment_method  \
# 5280     58412  complete          Computing          Payaxis
# 1157     11521  complete  Mobiles & Tablets          Payaxis
# 13057    72572  complete  Mobiles & Tablets          Easypay
# 11833    70786  complete      Men's Fashion       Easypay_MA
# 11099    69712  complete         Appliances          Easypay
# ...        ...       ...                ...              ...
# 3747     44309  complete  Mobiles & Tablets          Payaxis
# 11769    70689  complete         Appliances  easypay_voucher
# 4861     55231  complete         Appliances          Easypay
# 13899    73758  complete      Entertainment  easypay_voucher
# 6079     61173  complete  Mobiles & Tablets          Easypay
#
#                                   E Mail  respond_to_discount  total_spent  \
# 5280          tomas.joslin@earthlink.net                    1     2738.620
# 1157   demetrius.matamoros@microsoft.com                    1     3224.406
# 13057          larhonda.stacks@gmail.com                    1     9821.525
# 11833              cinda.yeary@gmail.com                    1      306.900
# 11099           abbie.hartness@gmail.com                    1      444.905
# ...                                  ...                  ...          ...
# 3747           ariana.seamon@yahoo.co.in                    1    18871.620
# 11769       alverta.carranza@comcast.net                    1     2608.200
# 4861            tyesha.swinson@gmail.com                    1      491.855
# 13899           sheldon.backus@gmail.com                    1    16958.000
# 6079              avery.raskin@gmail.com                    1     4979.900
#
#        total_discount_received  no_of_transactions  \
# 5280                   578.680                   9
# 1157                   991.994                  27
# 13057                 1444.975                  11
# 11833                   34.100                  10
# 11099                   54.995                   1
# ...                        ...                 ...
# 3747                  6402.480                  19
# 11769                  569.800                   4
# 4861                    29.445                   2
# 13899                 2000.000                   4
# 6079                   872.800                   8
#
#        days_till_last_interaction  ...  age_binned_Middle_Age  \
# 5280                          106  ...                      1
# 1157                          197  ...                      0
# 13057                         229  ...                      1
# 11833                         375  ...                      1
# 11099                         376  ...                      1
# ...                           ...  ...                    ...
# 3747                          370  ...                      1
# 11769                         375  ...                      0
# 4861                          338  ...                      1
# 13899                         372  ...                      1
# 6079                          355  ...                      1
#
#        age_binned_Old_age  Gender_F  Gender_M  Region_Midwest  \
# 5280                    0         0         1               1
# 1157                    1         0         1               0
# 13057                   0         1         0               0
# 11833                   0         1         0               0
# 11099                   0         1         0               0
# ...                   ...       ...       ...             ...
# 3747                    0         1         0               0
# 11769                   1         1         0               0
# 4861                    0         1         0               0
# 13899                   0         0         1               0
# 6079                    0         0         1               0
#
#        Region_Northeast  Region_South  Region_West  cluster  cluster_Cat
# 5280                  0             0            0        0            5
# 1157                  1             0            0        0            5
# 13057                 1             0            0        3            5
# 11833                 0             1            0        0            0
# 11099                 1             0            0        0            5
# ...                 ...           ...          ...      ...          ...
# 3747                  0             1            0        3            2
# 11769                 1             0            0        0            5
# 4861                  0             1            0        0            5
# 13899                 1             0            0        3            5
# 6079                  1             0            0        0            5
#
# [621 rows x 23 columns]

# %% [markdown]
# **Calculation Sample mean, sample standard deviation and standard error for each sample considering total_disocunt_recieved**

# %% [markdown]
# **Sample 1**

# %%
td_mean_s1 = sample1['total_discount_received'].mean()

# %%
td_std_s1 = np.std(sample1["total_discount_received"],ddof=1)

# %%
td_se_s1 = td_std_s1 / np.sqrt(sample_size_ci90)

# %%
print(f"Mean for sample 1: {td_mean_s1:.4f}")
print(f"Standard deviation for sample 1: {td_std_s1:.4f}")
print(f"Standard Error for sample 1: {td_se_s1:.4f}")
# Out:
# Mean for sample 1: 1421.8440
# Standard deviation for sample 1: 1932.9868
# Standard Error for sample 1: 118.9671

# %% [markdown]
# **Sample 2**

# %%
td_mean_s2 = np.mean(sample2["total_discount_received"])

# %%
td_std_s2 = np.std(sample2["total_discount_received"],ddof=1)

# %%
td_se_s2 = td_std_s2 / np.sqrt(sample_size_ci95)

# %%
print(f"Mean for sample 2: {td_mean_s2:.4f}")
print(f"Standard deviation for sample 2: {td_std_s2:.4f}")
print(f"Standard Error for sample 2: {td_se_s2:.4f}")
# Out:
# Mean for sample 2: 1574.2614
# Standard deviation for sample 2: 2596.3626
# Standard Error for sample 2: 134.9785

# %% [markdown]
# **Sample 3**

# %%
td_mean_s3 = np.mean(sample3["total_discount_received"])

# %%
td_std_s3 = np.std(sample3["total_discount_received"],ddof=1)

# %%
td_se_s3 = td_std_s3 / np.sqrt(sample_size_ci99)

# %%
print(f"Mean for sample 3: {td_mean_s3:.4f}")
print(f"Standard deviation for sample 3: {td_std_s3:.4f}")
print(f"Standard Error for sample 3: {td_se_s3:.4f}")
# Out:
# Mean for sample 3: 1527.6129
# Standard deviation for sample 3: 2418.6524
# Standard Error for sample 3: 97.0572

# %%
tb2 = {'Sample': ['Sample 1', 'Sample 2', 'Sample 3'],
        'Mean': [td_mean_s1,td_mean_s2,td_mean_s3],
        'Standard Deviation': [td_std_s1,td_std_s2,td_std_s3],
        'Standard Error': [td_se_s1,td_se_s2,td_se_s3]}

total_discount_summeries = pd.DataFrame(tb2)

# Print the DataFrame
print(total_discount_summeries)
# Out:
#      Sample         Mean  Standard Deviation  Standard Error
# 0  Sample 1  1421.844010         1932.986763      118.967111
# 1  Sample 2  1574.261444         2596.362573      134.978463
# 2  Sample 3  1527.612948         2418.652371       97.057176

# %%
data1 = {'Confidense Interval':['90%','95%','99%']
        , 'Sample Size':[sample_size_ci90,sample_size_ci95,sample_size_ci99]
        , 'Discount Mean':[td_mean_s1,td_mean_s2,td_mean_s3]
        ,'Real Discount Mean':[population_total_discount_received_mean,population_total_discount_received_mean,population_total_discount_received_mean]}

# %%
df1=pd.DataFrame(data1)
df1
# Out:
#   Confidense Interval  Sample Size  Discount Mean  Real Discount Mean
# 0                 90%          264    1421.844010             1459.16
# 1                 95%          370    1574.261444             1459.16
# 2                 99%          621    1527.612948             1459.16

# %%
df1['Absolute Error'] = abs(df1['Real Discount Mean'] - df1['Discount Mean'])
df1
# Out:
#   Confidense Interval  Sample Size  Discount Mean  Real Discount Mean  \
# 0                 90%          264    1421.844010             1459.16
# 1                 95%          370    1574.261444             1459.16
# 2                 99%          621    1527.612948             1459.16
#
#    Absolute Error
# 0       37.315990
# 1      115.101444
# 2       68.452948

# %%
import math

# Set the given values
z_scores = [1.645, 1.96, 2.576] # z-score values for 90%, 95%, and 99% confidence intervals
margin_of_error = 0.05
population_proportion = 0.5
population_size = 9521

# Calculate the sample size for each confidence interval
sample_sizes = []
for z in z_scores:
    sample_size = (((z**2) * population_proportion * (1 - population_proportion)) / (margin_of_error**2)) / (1+ ((z**2) * population_proportion * (1 - population_proportion))/((margin_of_error**2)*population_size))
    sample_size = math.ceil(sample_size) # Round up to the nearest integer
    sample_sizes.append(sample_size)

print("Sample sizes needed for 90%, 95%, and 99% confidence intervals:", sample_sizes)
# Out:
# Sample sizes needed for 90%, 95%, and 99% confidence intervals: [264, 370, 621]
